# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import bs4
from bs4 import BeautifulSoup
import urllib.request
import re  # real warriors do it with RegEx
import pgeocode # module to convert an address into latitude and longitude values
import json
# !pip3 install geojson
# Out:
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Installing collected packages: geojson
# Successfully installed geojson-2.5.0
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import pprint
import folium

# %%
## bounding boxes (.geojson)

# %%
del dPostCodeGJSON

# %%
featurelist = []

PostCodeAreas = ['SE','SW','W','NW','N','E','EC','WC']

for area in PostCodeAreas:
    with open(area + '.geojson') as f:
        data = json.load(f)
        d1 = data['features']
        for postcode in d1:
            #print(postcode['properties']['name'])
            featurelist.append(postcode)

dPostCodeGJSON = {'type': 'FeatureCollection', 'features' : featurelist}

# %%
len(dPostCodeGJSON['features'])
# Out:
# 171

# %%
dPostCodeGJSON['features'][0].keys()
# Out:
# dict_keys(['type', 'geometry', 'properties'])

# %%
dPostCodeGJSON['features'][100]['properties']
# Out:
# {'name': 'N9',
#  'styleUrl': '#N',
#  'styleHash': '-7b021fd',
#  'description': 'N9 postcode district',
#  'fill': '#009f00',
#  'fill-opacity': 0.4980392156862745}

# %%
dPostCodeGJSON['features'][157]['geometry']['coordinates'][0]
# Out:
# [[-0.12787, 51.51617],
#  [-0.1272, 51.51638],
#  [-0.12675, 51.51664],
#  [-0.12676, 51.51665],
#  [-0.12647, 51.51695],
#  [-0.1265, 51.51704],
#  [-0.12592, 51.51702],
#  [-0.12591, 51.51701],
#  [-0.12569, 51.51701],
#  [-0.12563, 51.51693],
#  [-0.12563, 51.51689],
#  [-0.12588, 51.51671],
#  [-0.1258, 51.51666],
#  [-0.12554, 51.51664],
#  [-0.1255, 51.51661],
#  [-0.12537, 51.51657],
#  [-0.12541, 51.51641],
#  [-0.12528, 51.51625],
#  [-0.12444, 51.51657],
#  [-0.12339, 51.51735],
#  [-0.12292, 51.51778],
#  [-0.12284, 51.51778],
#  [-0.1226, 51.51742],
#  [-0.12227, 51.51771],
#  [-0.12224, 51.51778],
#  [-0.12221, 51.51779],
#  [-0.12189, 51.51765],
#  [-0.12146, 51.51775],
#  [-0.12099, 51.51809],
#  [-0.12089, 51.51811],
#  [-0.12212, 51.51963],
#  [-0.12212, 51.52009],
#  [-0.12213, 51.52009],
#  [-0.12262, 51.52017],
#  [-0.12277, 51.52008],
#  [-0.12295, 51.52003],
#  [-0.12315, 51.52003],
#  [-0.12317, 51.51992],
#  [-0.12325, 51.5198],
#  [-0.12355, 51.51964],
#  [-0.12365, 51.51966],
#  [-0.12402, 51.51938],
#  [-0.12382, 51.51918],
#  [-0.1241, 51.51908],
#  [-0.12407, 51.51879],
#  [-0.12406, 51.51877],
#  [-0.12407, 51.51873],
#  [-0.12417, 51.51871],
#  [-0.12442, 51.51858],
#  [-0.12487, 51.51835],
#  [-0.12514, 51.51828],
#  [-0.12521, 51.51816],
#  [-0.12524, 51.51814],
#  [-0.12552, 51.51813],
#  [-0.12552, 51.51813],
#  [-0.12559, 51.51821],
#  [-0.12603, 51.5181],
#  [-0.12601, 51.51805],
#  [-0.12627, 51.51791],
#  [-0.12629, 51.51792],
#  [-0.12643, 51.51791],
#  [-0.12661, 51.51783],
#  [-0.12665, 51.51784],
#  [-0.12679, 51.51777],
#  [-0.1268, 51.51777],
#  [-0.12691, 51.51777],
#  [-0.12704, 51.51772],
#  [-0.12706, 51.51767],
#  [-0.12692, 51.51754],
#  [-0.12692, 51.51749],
#  [-0.12678, 51.51743],
#  [-0.12672, 51.51737],
#  [-0.12665, 51.51733],
#  [-0.12663, 51.51731],
#  [-0.12656, 51.51722],
#  [-0.12655, 51.51718],
#  [-0.12657, 51.51708],
#  [-0.12696, 51.51698],
#  [-0.12714, 51.51712],
#  [-0.12741, 51.51707],
#  [-0.12763, 51.51714],
#  [-0.12754, 51.51727],
#  [-0.12809, 51.51748],
#  [-0.12811, 51.51716],
#  [-0.12865, 51.51702],
#  [-0.12867, 51.51703],
#  [-0.12926, 51.51695],
#  [-0.1294, 51.51711],
#  [-0.12974, 51.51708],
#  [-0.12996, 51.51701],
#  [-0.12996, 51.51685],
#  [-0.13038, 51.51668],
#  [-0.13036, 51.51642],
#  [-0.13018, 51.51623],
#  [-0.13017, 51.51589],
#  [-0.1301, 51.51588],
#  [-0.13, 51.51588],
#  [-0.12944, 51.51599],
#  [-0.12938, 51.51602],
#  [-0.12927, 51.51624],
#  [-0.1287, 51.5163],
#  [-0.12862, 51.51622],
#  [-0.12802, 51.51622],
#  [-0.12787, 51.51617]]

# %%
index = {'index', 'key'}

# %%
for i, ditem in enumerate(dPostCodeGJSON['features']):
    print("{} : {}, {}".format(i, ditem['properties']['name'], ditem['properties']['styleUrl']))
# Out:
# 0 : SE1, #SE
# 1 : SE2, #SE
# 2 : SE3, #SE
# 3 : SE4, #SE
# 4 : SE5, #SE
# 5 : SE6, #SE
# 6 : SE7, #SE
# 7 : SE8, #SE
# 8 : SE9, #SE
# 9 : SE10, #SE
# 10 : SE11, #SE
# 11 : SE12, #SE
# 12 : SE13, #SE
# 13 : SE14, #SE
# 14 : SE15, #SE
# 15 : SE16, #SE
# 16 : SE17, #SE
# 17 : SE18, #SE
# 18 : SE19, #SE
# 19 : SE20, #SE
# 20 : SE21, #SE
# 21 : SE22, #SE
# 22 : SE23, #SE
# 23 : SE24, #SE
# 24 : SE25, #SE
# 25 : SE26, #SE
# 26 : SE27, #SE
# 27 : SE28, #SE
# 28 : SW1A, #SW1
# 29 : SW1E, #SW1
# 30 : SW1H, #SW1
# 31 : SW1P, #SW1
# 32 : SW1V, #SW1
# 33 : SW1W, #SW1
# 34 : SW1X, #SW1
# 35 : SW1Y, #SW1
# 36 : SW2, #SW
# 37 : SW3, #SW
# 38 : SW4, #SW
# 39 : SW5, #SW
# 40 : SW6, #SW
# 41 : SW7, #SW
# 42 : SW8, #SW
# 43 : SW9, #SW
# 44 : SW10, #SW
# 45 : SW11, #SW
# 46 : SW12, #SW
# 47 : SW13, #SW
# 48 : SW14, #SW
# 49 : SW15, #SW
# 50 : SW16, #SW
# 51 : SW17, #SW
# 52 : SW18, #SW
# 53 : SW19, #SW
# 54 : SW20, #SW
# 55 : W1B, #W1
# 56 : W1C, #W1
# 57 : W1D, #W1
# 58 : W1F, #W1
# 59 : W1G, #W1
# 60 : W1H, #W1
# 61 : W1J, #W1
# 62 : W1K, #W1
# 63 : W1S, #W1
# 64 : W1T, #W1
# 65 : W1U, #W1
# 66 : W1W, #W1
# 67 : W2, #W
# 68 : W3, #W
# 69 : W4, #W
# 70 : W5, #W
# 71 : W6, #W
# 72 : W7, #W
# 73 : W8, #W
# 74 : W9, #W
# 75 : W10, #W
# 76 : W11, #W
# 77 : W12, #W
# 78 : W13, #W
# 79 : W14, #W
# 80 : NW1, #NW
# 81 : NW2, #NW
# 82 : NW3, #NW
# 83 : NW4, #NW
# 84 : NW5, #NW
# 85 : NW6, #NW
# 86 : NW7, #NW
# 87 : NW8, #NW
# 88 : NW9, #NW
# 89 : NW10, #NW
# 90 : NW11, #NW
# 91 : N1, #N1
# 92 : N1C, #N1
# 93 : N2, #N
# 94 : N3, #N
# 95 : N4, #N
# 96 : N5, #N
# 97 : N6, #N
# 98 : N7, #N
# 99 : N8, #N
# 100 : N9, #N
# 101 : N10, #N
# 102 : N11, #N
# 103 : N12, #N
# 104 : N13, #N
# 105 : N14, #N
# 106 : N15, #N
# 107 : N16, #N
# 108 : N17, #N
# 109 : N18, #N
# 110 : N19, #N
# 111 : N20, #N
# 112 : N21, #N
# 113 : N22, #N
# 114 : E1, #E1
# 115 : E1W, #E1
# 116 : E2, #E
# 117 : E3, #E
# 118 : E4, #E
# 119 : E5, #E
# 120 : E6, #E
# 121 : E7, #E
# 122 : E8, #E
# 123 : E9, #E
# 124 : E10, #E
# 125 : E11, #E
# 126 : E12, #E
# 127 : E13, #E
# 128 : E14, #E
# 129 : E15, #E
# 130 : E16, #E
# 131 : E17, #E
# 132 : E18, #E
# 133 : E20, #E
# 134 : EC1A, #EC1
# 135 : EC1M, #EC1
# 136 : EC1N, #EC1
# 137 : EC1R, #EC1
# 138 : EC1V, #EC1
# 139 : EC1Y, #EC1
# 140 : EC2A, #EC2
# 141 : EC2M, #EC2
# 142 : EC2N, #EC2
# 143 : EC2R, #EC2
# 144 : EC2V, #EC2
# 145 : EC2Y, #EC2
# 146 : EC3A, #EC3
# 147 : EC3M, #EC3
# 148 : EC3N, #EC3
# 149 : EC3R, #EC3
# 150 : EC3V, #EC3
# 151 : EC4A, #EC4
# 152 : EC4M, #EC4
# 153 : EC4N, #EC4
# 154 : EC4R, #EC4
# 155 : EC4V, #EC4
# 156 : EC4Y, #EC4
# 157 : WC1A, #WC1
# 158 : WC1B, #WC1
# 159 : WC1E, #WC1
# 160 : WC1H, #WC1
# 161 : WC1N, #WC1
# 162 : WC1R, #WC1
# 163 : WC1V, #WC1
# 164 : WC1X, #WC1
# 165 : WC2A, #WC2
# 166 : WC2B, #WC2
# 167 : WC2E, #WC2
# 168 : WC2H, #WC2
# 169 : WC2N, #WC2
# 170 : WC2R, #WC2

# %%
newcoordinates = pd.Series()

for i, ditem in enumerate(dPostCodeGJSON['features'][157:165]):
        print("{} : {}, {}".format(i, ditem['properties']['name'], ditem['properties']['styleUrl']))
        print("{}".format(len(ditem['geometry']['coordinates'][0])))
        newcoordinates = newcoordinates.append(pd.Series(ditem['geometry']['coordinates'][0]))

# %%
def get_bounding_box(geojson: dict, outcode: str):

    newcoordinates = pd.Series()

    for i, ditem in enumerate(geojson):
            newcoordinates = newcoordinates.append(pd.Series(ditem['geometry']['coordinates'][0]))

    newcoordinates.reset_index(drop=True, inplace=True)
    uniquecoordinates = newcoordinates.loc[newcoordinates.astype(str).drop_duplicates(keep = False).index]
    
    return(uniquecoordinates, str)
# Out:
# 0 : WC1A, #WC1
# 104
# 1 : WC1B, #WC1
# 168
# 2 : WC1E, #WC1
# 110
# 3 : WC1H, #WC1
# 167
# 4 : WC1N, #WC1
# 164
# 5 : WC1R, #WC1
# 99
# 6 : WC1V, #WC1
# 127
# 7 : WC1X, #WC1
# 299
# <ipython-input-229-a10e627c8d77>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   newcoordinates = pd.Series()

# %%
newcoordinates.reset_index(drop=True, inplace=True)

# %%
newcoordinates
# Out:
# 0       [-0.12787, 51.51617]
# 1        [-0.1272, 51.51638]
# 2       [-0.12675, 51.51664]
# 3       [-0.12676, 51.51665]
# 4       [-0.12647, 51.51695]
#                 ...
# 1233    [-0.11202, 51.51908]
# 1234    [-0.11204, 51.51904]
# 1235    [-0.11192, 51.51891]
# 1236     [-0.1119, 51.51883]
# 1237    [-0.11152, 51.51835]
# Length: 1238, dtype: object

# %%
uniquecoordinates = newcoordinates.loc[newcoordinates.astype(str).drop_duplicates(keep = False).index]

# %%
uniquecoordinates.shape
# Out:
# (343,)

# %%
newcoord.groupby('xy').count()
#Lon_4sq_venues.groupby('Venue_category').count().sort_values('Venue', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-227-4cd500767b26> in <module>
# ----> 1 newcoord.groupby('xy').count()
#       2 #Lon_4sq_venues.groupby('Venue_category').count().sort_values('Venue', ascending=False)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/generic.py in count(self)
#    1732         """
#    1733         data = self._get_data_to_aggregate()
# -> 1734         ids, _, ngroups = self.grouper.group_info
#    1735         mask = ids != -1
#    1736
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     298     @cache_readonly
#     299     def group_info(self):
# --> 300         comp_ids, obs_group_ids = self._get_compressed_codes()
#     301
#     302         ngroups = len(obs_group_ids)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     316     @final
#     317     def _get_compressed_codes(self) -> Tuple[np.ndarray, np.ndarray]:
# --> 318         all_codes = self.codes
#     319         if len(all_codes) > 1:
#     320             group_index = get_group_index(all_codes, self.shape, sort=True, xnull=True)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/ops.py in codes(self)
#     257     @property
#     258     def codes(self) -> List[np.ndarray]:
# --> 259         return [ping.codes for ping in self.groupings]
#     260
#     261     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     257     @property
#     258     def codes(self) -> List[np.ndarray]:
# --> 259         return [ping.codes for ping in self.groupings]
#     260
#     261     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in codes(self)
#     589     def codes(self) -> np.ndarray:
#     590         if self._codes is None:
# --> 591             self._make_codes()
#     592         return self._codes
#     593
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in _make_codes(self)
#     621             else:
#     622                 na_sentinel = -1
# --> 623             codes, uniques = algorithms.factorize(
#     624                 self.grouper, sort=self.sort, na_sentinel=na_sentinel
#     625             )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     720             na_value = None
#     721
# --> 722         codes, uniques = factorize_array(
#     723             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     724         )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     526
#     527     table = hash_klass(size_hint or len(values))
# --> 528     uniques, codes = table.factorize(
#     529         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     530     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
london_map.choropleth(
    geo_data=dPostCodeGJSON,
    data=df_can,
    columns=['Country', 'Total'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Immigration to Canada'
)

map_Lon = folium.Map(location=[51.51, -0.10], zoom_start=12)

# add markers to map
for lat, lng, category in zip(Lon_4sq_venues['Venue_latitude'], Lon_4sq_venues['Venue_longitude'], Lon_4sq_venues['Venue_category']):
    label = folium.Popup(category, parse_html=True)
    paintcolor  = rainbow[df_categories.index.get_loc(category) % 24]
    
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=paintcolor,     #'blue',
        fill=True,
        fill_color=paintcolor,  # fill_color='#3186cc',
        fill_opacity=0.33,
        parse_html=False).add_to(map_Lon)

# %%
## Tube data

# %%
pdTFL_tubes = pd.read_csv('https://www.whatdotheyknow.com/request/512947/response/1238210/attach/3/Stations%2020180921.csv.txt?cookie_passthrough=1')

print('Data downloaded!')
print('len : {}'.format(len(pdTFL_tubes)))
# Out:
# Data downloaded!
# len : 479

# %%
pdTFL_tubes.drop(['OBJECTID','EASTING','NORTHING'], axis = 1, inplace=True) # don't need these (Easting is OS equivalent of x)
pdTFL_tubes.rename(columns = {'x':'latitude', 'y':'longitude'}, inplace = True)  # we do need these : y is latitude

pdTFL_tubes = pdTFL_tubes.dropna()  # drop the 200 or so observations that are not part of a London Underground line (i.e. Rail, Overground etc)
pdTFL_tubes[0:5]
# Out:
#    FID           NAME             LINES             NETWORK  Zone  latitude  \
# 0    0         Temple  District, Circle  London Underground     1 -0.112644
# 1    1    Blackfriars  District, Circle  London Underground     1 -0.102020
# 2    2  Mansion House  District, Circle  London Underground     1 -0.092495
# 3    3  Cannon Street  District, Circle  London Underground     1 -0.088801
# 4    4       Monument  District, Circle  London Underground     1 -0.084502
#
#    longitude
# 0  51.510474
# 1  51.511114
# 2  51.511306
# 3  51.510963
# 4  51.510209

# %%
pdTFL_tubes.shape
# Out:
# (271, 7)

# %%
type(pdTFL_tubes['latitude'][1])
# Out:
# numpy.float64

# %%
map_Lon = folium.Map(location=[51.51, -0.10], zoom_start=12)

for lat, lng, name in zip(pdTFL_tubes['longitude'], pdTFL_tubes['latitude'], pdTFL_tubes['NAME']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html=True)
    
    folium.CircleMarker(
        [lat, lng],
        radius=6, # define how big you want the circle markers to be
        popup = label,
        color='red',
        fill=True,
        fill_color='3186cc',
        fill_opacity=0.6
    ).add_to(map_Lon)


map_Lon
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_10141112832441a9a341bed76f131e29%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_10141112832441a9a341bed76f131e29%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_10141112832441a9a341bed76f131e29%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_10141112832441a9a341bed76f131e29%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.51%2C%20-0.1%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20c ...

# %%
TFL_Tube_Flows = "https://data.london.gov.uk/download/london-underground-performance-reports/b6ab04fc-9062-4291-b514-7fa218073b4c/multi-year-station-entry-and-exit-figures.xls"

urllib.request.urlretrieve(TFL_Tube_Flows, "TFL_multi-year-station-entry-and-exit-figures.xls")  # For Python 3
# Out:
# ('TFL_multi-year-station-entry-and-exit-figures.xls',
#  <http.client.HTTPMessage at 0x11b547880>)

# %%
pdTFL_Tube_Flows = pd.read_excel('TFL_multi-year-station-entry-and-exit-figures.xls', 
                                 sheet_name = 1, # Latest year only please (it's 2017 Entry & Exit)
                                 usecols = "A:C,E:K", # columns we care: index, category, years 2021-2030
                                 skiprows = 6)

# %%
#pdTFL_Tube_Flows.head()
pdTFL_Tube_Flows.rename(columns = {'Weekday.1':'Weekday_ex', 'Saturday.1':'Saturday_ex', 'Sunday.1':'Sunday_ex'}, inplace = True)  # we do need these : y is latitude
pdTFL_Tube_Flows.dropna(inplace = True)

print(pdTFL_Tube_Flows.shape)
pdTFL_Tube_Flows.head()
# Out:
# (268, 10)

# %%
LonConsumerExpendEst_Data = "https://data.london.gov.uk/download/london-consumer-expenditure-estimates-2011-2036/322f914f-5ca0-4ae2-8d25-fc8443f9e6e8/aggregated-postal-base-greater-london.xls"

urllib.request.urlretrieve(LonConsumerExpendEst_Data, "LonConsumerExpendEst_Data.xls")  # For Python 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-310-61d4179285d3> in <module>
#       3 urllib.request.urlretrieve(LonConsumerExpendEst_Data, "LonConsumerExpendEst_Data.xls")  # For Python 3
#       4
# ----> 5 pdConsumerWallet = read_excel('LonConsumerExpendEst_Data.xls', sheet_name = 'Barnet')
#
# NameError: name 'read_excel' is not defined

# %%
pdTFL_Tube_Flows['average_flow'] = pdTFL_Tube_Flows['million']*(1000.0/364.0)

# %%
pdTFL_Tube_Flows.head()
# Out:
#      nlc       Station         Borough  Weekday  Saturday   Sunday  \
# 0  500.0    Acton Town          Ealing   9531.0    6716.0   4744.0
# 1  502.0       Aldgate  City of London  15080.0    4397.0   3261.0
# 2  503.0  Aldgate East   Tower Hamlets  22327.0   16166.0  13323.0
# 3  505.0      Alperton           Brent   4495.0    3279.0   2345.0
# 4  506.0      Amersham        Chiltern   3848.0    1876.0   1232.0
#
#    Weekday_ex  Saturday_ex  Sunday_ex    million  average_flow
# 0      9382.0       6617.0     4785.0   6.040516     16.594824
# 1     16023.0       5909.0     4230.0   8.846940     24.304780
# 2     21071.0      13893.0    11347.0  13.998292     38.456846
# 3      5081.0       3392.0     2445.0   3.052230      8.385247
# 4      4025.0       1797.0     1121.0   2.321692      6.378275

# %%
pdTFL_Tube_Flows.dropna(inplace = True)

# %%
pdTFL_Tube_Flows['million'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pdTFL_Tube_Flows.set_index('Station')
# Out:
#                   nlc                 Borough  Weekday  Saturday   Sunday  \
# Station
# Acton Town      500.0                  Ealing   9531.0    6716.0   4744.0
# Aldgate         502.0          City of London  15080.0    4397.0   3261.0
# Aldgate East    503.0           Tower Hamlets  22327.0   16166.0  13323.0
# Alperton        505.0                   Brent   4495.0    3279.0   2345.0
# Amersham        506.0                Chiltern   3848.0    1876.0   1232.0
# ...               ...                     ...      ...       ...      ...
# Wimbledon Park  768.0                  Merton   3583.0    2648.0   1605.0
# Wood Green      770.0                Haringey  20042.0   15815.0  11793.0
# Wood Lane       599.0  Hammersmith and Fulham   6242.0    4516.0   2267.0
# Woodford        769.0               Redbridge   9442.0    6937.0   4140.0
# Woodside Park   771.0                  Barnet   5311.0    2997.0   2246.0
#
#                 Weekday_ex  Saturday_ex  Sunday_ex    million  average_flow
# Station
# Acton Town          9382.0       6617.0     4785.0   6.040516     16.594824
# Aldgate            16023.0       5909.0     4230.0   8.846940     24.304780
# Aldgate East       21071.0      13893.0    11347.0  13.998292     38.456846
# Alperton            5081.0       3392.0     2445.0   3.052230      8.385247
# Amersham            4025.0       1797.0     1121.0   2.321692      6.378275
# ...                    ...          ...        ...        ...           ...
# Wimbledon Park      3301.0       2235.0     1600.0   2.184663      6.001821
# Wood Green         18949.0      16020.0    11415.0  12.889415     35.410481
# Wood Lane           6631.0       4294.0     2494.0   3.995888     10.977714
# Woodford            9537.0       6301.0     4142.0   5.978701     16.425003
# Woodside Park       6089.0       3760.0     2967.0   3.543131      9.733876
#
# [268 rows x 10 columns]

# %%
pdConsumerWallet
# Out:
# Empty DataFrame
# Columns: [Postal Code, Sector, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]
# Index: []
